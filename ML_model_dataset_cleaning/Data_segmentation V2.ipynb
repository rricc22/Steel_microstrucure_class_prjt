# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

# %%
def load_and_resize_images(image_dir, mask_dir, target_size=(256, 256)):
    images = []
    masks = []

    image_files = [f for f in os.listdir(image_dir) if f.endswith('.png')]
    for image_file in image_files:
        image_path = os.path.join(image_dir, image_file)
        mask_path = os.path.join(mask_dir, image_file)  # Assurez-vous que les masques ont le même nom de fichier

        image = cv2.imread(image_path, cv2.IMREAD_COLOR)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Les masques sont souvent en niveaux de gris

        image = cv2.resize(image, target_size)
        mask = cv2.resize(mask, target_size)

        images.append(image)
        masks.append(mask)

    return np.array(images), np.array(masks)

# %%
image_dir = '/home/riccardo/Visual_Studio_Code/Grain-segmentation_prjt/dataset/martensite microstructure/converted_to_png'
mask_dir = '/home/riccardo/Visual_Studio_Code/Grain-segmentation_prjt/dataset/martensite microstructure/martensite_microstructure_preprocessed'

# %%
X, Y = load_and_resize_images(image_dir, mask_dir)

# %%
X_scaled = X / 255.0
Y_scaled = Y / 255.0  # Assurez-vous que vos masques sont également sur une échelle de 0 à 255 avant de faire ça.

# %% [markdown]
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# datagen = ImageDataGenerator(rotation_range=20,horizontal_flip=True,featurewise_center=True,width_shift_range=0.2,
#     height_shift_range=0.2,validation_split=0.2)
#
# datagen.fit(X_scaled)

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError

def create_vgg(input_size):
    # Chargez le modèle VGG16 pré-entraîné sans les couches supérieures (top)
    vgg = VGG16(include_top=False, weights='imagenet', input_shape=input_size)

    # Bloquez les couches VGG pour ne pas les entraîner
    for layer in vgg.layers:
        layer.trainable = False

    # Extraction des couches intermédiaires pour les connexions de saut
    block1_conv2 = vgg.get_layer('block1_conv2').output
    block2_conv2 = vgg.get_layer('block2_conv2').output
    block3_conv3 = vgg.get_layer('block3_conv3').output
    block4_conv3 = vgg.get_layer('block4_conv3').output
    block5_conv3 = vgg.get_layer('block5_conv3').output

    # Partie d'expansion (U-Net)
    # Démarrez avec la sortie du dernier bloc VGG
    x = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding='same')(block5_conv3)
    x = concatenate([x, block4_conv3])
    x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)

    x = Conv2DTranspose(256, (3, 3), strides=(2, 2), padding='same')(x)
    x = concatenate([x, block3_conv3])
    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)

    x = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same')(x)
    x = concatenate([x, block2_conv2])
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)

    x = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(x)
    x = concatenate([x, block1_conv2])
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)

    # Couche de sortie
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(x)

    model = Model(inputs=vgg.input, outputs=outputs)
    return model

# Créer le modèle U-Net basé sur VGG16
input_size = (256, 256, 3)  # Ajustez à la taille de vos images
model = create_vgg(input_size)

# Compiler le modèle
model.compile(optimizer=Adam(lr=1e-4), loss=MeanSquaredError(), metrics=['mae'])

# Afficher le résumé du modèle
model.summary()

# Entraîner le modèle avec vos données
# Assurez-vous que vos données sont préparées correctement
# history = model.fit(X_train, Y_train, ...)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 256, 256, 64) 1792        input_4[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 256, 256, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 128, 128, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 128, 128, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 128, 128, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 64, 64, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 64, 64, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 64, 64, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 64, 64, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 32, 32, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 32, 32, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 32, 32, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 32, 32, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 16, 16, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 16, 16, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 16, 16, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 16, 16, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 32, 32, 512)  2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 32, 32, 1024) 0           conv2d_transpose_12[0][0]
#                                                                  block4_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 64, 64, 256)  1179904     conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 64, 64, 512)  0           conv2d_transpose_13[0][0]
#                                                                  block3_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 128, 128, 128 295040      conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 128, 128, 256 0           conv2d_transpose_14[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 256, 256, 64) 73792       conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 256, 256, 128 0           conv2d_transpose_15[0][0]
#                                                                  block1_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 1)  65          conv2d_18[0][0]
# ==================================================================================================
# Total params: 24,891,137
# Trainable params: 10,176,449
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %% [markdown]
# model = unet_model()

# %% [markdown]
# history = model.fit(datagen.flow(X_scaled, Y_scaled, subset='training',batch_size=2), validation_data=datagen.flow(X_scaled, Y_scaled,
#          batch_size=2, subset='validation'),epochs=50)

# %%
history = model.fit(X_scaled, Y_scaled, epochs=300, batch_size=2, validation_split=0.1)
# Out:
# Epoch 1/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0257 - mae: 0.1230 - val_loss: 0.0504 - val_mae: 0.1732
# Epoch 2/300
# 28/28 [==============================] - 3s 121ms/step - loss: 0.0252 - mae: 0.1221 - val_loss: 0.0507 - val_mae: 0.1752
# Epoch 3/300
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0244 - mae: 0.1197 - val_loss: 0.0503 - val_mae: 0.1747
# Epoch 4/300
# 28/28 [==============================] - 3s 120ms/step - loss: 0.0247 - mae: 0.1207 - val_loss: 0.0515 - val_mae: 0.1735
# Epoch 5/300
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0242 - mae: 0.1184 - val_loss: 0.0584 - val_mae: 0.1918
# Epoch 6/300
# 28/28 [==============================] - 3s 121ms/step - loss: 0.0251 - mae: 0.1213 - val_loss: 0.0563 - val_mae: 0.1837
# Epoch 7/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0238 - mae: 0.1180 - val_loss: 0.0558 - val_mae: 0.1852
# Epoch 8/300
# 28/28 [==============================] - 3s 121ms/step - loss: 0.0233 - mae: 0.1160 - val_loss: 0.0535 - val_mae: 0.1795
# Epoch 9/300
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0230 - mae: 0.1152 - val_loss: 0.0553 - val_mae: 0.1822
# Epoch 10/300
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0228 - mae: 0.1148 - val_loss: 0.0525 - val_mae: 0.1780
# Epoch 11/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0229 - mae: 0.1161 - val_loss: 0.0530 - val_mae: 0.1758
# Epoch 12/300
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0229 - mae: 0.1149 - val_loss: 0.0555 - val_mae: 0.1856
# Epoch 13/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0225 - mae: 0.1144 - val_loss: 0.0532 - val_mae: 0.1780
# Epoch 14/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0218 - mae: 0.1122 - val_loss: 0.0532 - val_mae: 0.1776
# Epoch 15/300
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0214 - mae: 0.1109 - val_loss: 0.0554 - val_mae: 0.1816
# Epoch 16/300
# 28/28 [==============================] - 4s 132ms/step - loss: 0.0214 - mae: 0.1110 - val_loss: 0.0543 - val_mae: 0.1809
# Epoch 17/300
# 28/28 [==============================] - 4s 128ms/step - loss: 0.0214 - mae: 0.1112 - val_loss: 0.0554 - val_mae: 0.1819
# Epoch 18/300
# 28/28 [==============================] - 4s 128ms/step - loss: 0.0210 - mae: 0.1097 - val_loss: 0.0560 - val_mae: 0.1802
# Epoch 19/300
# 28/28 [==============================] - 4s 127ms/step - loss: 0.0222 - mae: 0.1139 - val_loss: 0.0527 - val_mae: 0.1741
# Epoch 20/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.
300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0118 - mae: 0.0805 - val_loss: 0.0691 - val_mae: 0.1933
# Epoch 116/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0117 - mae: 0.0799 - val_loss: 0.0698 - val_mae: 0.1943
# Epoch 117/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0112 - mae: 0.0782 - val_loss: 0.0702 - val_mae: 0.1944
# Epoch 118/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0111 - mae: 0.0778 - val_loss: 0.0706 - val_mae: 0.1942
# Epoch 119/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0118 - mae: 0.0805 - val_loss: 0.0709 - val_mae: 0.1962
# Epoch 120/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0113 - mae: 0.0786 - val_loss: 0.0722 - val_mae: 0.1960
# Epoch 121/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0114 - mae: 0.0790 - val_loss: 0.0722 - val_mae: 0.1968
# Epoch 122/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0111 - mae: 0.0780 - val_loss: 0.0717 - val_mae: 0.1969
# Epoch 123/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0110 - mae: 0.0775 - val_loss: 0.0727 - val_mae: 0.1986
# Epoch 124/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0108 - mae: 0.0765 - val_loss: 0.0714 - val_mae: 0.1960
# Epoch 125/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0108 - mae: 0.0769 - val_loss: 0.0695 - val_mae: 0.1929
# Epoch 126/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0109 - mae: 0.0769 - val_loss: 0.0716 - val_mae: 0.1968
# Epoch 127/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0108 - mae: 0.0763 - val_loss: 0.0721 - val_mae: 0.1970
# Epoch 128/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0108 - mae: 0.0769 - val_loss: 0.0722 - val_mae: 0.1985
# Epoch 129/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0112 - mae: 0.0792 - val_loss: 0.0731 - val_mae: 0.1971
# Epoch 130/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0112 - mae: 0.0787 - val_loss: 0.0722 - val_mae: 0.1989
# Epoch 131/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0113 - mae: 0.0788 - val_loss: 0.0718 - val_mae: 0.1964
# Epoch 132/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0109 - mae: 0.0773 - val_loss: 0.0694 - val_mae: 0.1918
# Epoch 133/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0110 - mae: 0.0777 - val_loss: 0.0743 - val_mae: 0.2001
# Epoch 134/300
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0110 - mae: 0.0780 - val_loss: 0.0732 - val_mae: 0.1992
# Epoch 135/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0106 - mae: 0.0759 - val_loss: 0.0712 - val_mae: 0.1955
# Epoch 136/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0106 - mae: 0.0756 - val_loss: 0.0699 - val_mae: 0.1942
# Epoch 137/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0114 - mae: 0.0791 - val_loss: 0.0751 - val_mae: 0.2045
# Epoch 138/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0114 - mae: 0.0798 - val_loss: 0.0747 - val_mae: 0.2019
# Epoch 139/300
# 28/28 [==============================] - 4s 129ms/step - loss: 0.0112 - mae: 0.0788 - val_loss: 0.0712 - val_mae: 0.1941
# Epoch 140/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0107 - mae: 0.0766 - val_loss: 0.0709 - val_mae: 0.1937
# Epoch 141/300
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0108 - mae: 0.0767 - val_loss: 0.0723 - val_mae: 0.1981
# Epoch 142/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0101 - mae: 0.0741 - val_loss: 0.0716 - val_mae: 0.1956
# Epoch 143/300
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0100 - mae: 0.0733 - val_loss: 0.0705 - val_mae: 0.1928
# Epoch 144/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0099 - mae: 0.0731 - val_loss: 0.0735 - val_mae: 0.1981
# Epoch 145/300
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0098 - mae: 0.0726 - val_loss: 0.0721 - val_mae: 0.1963
# Epoch 146/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0098 - mae: 0.0728 - val_loss: 0.0743 - val_mae: 0.1995
# Epoch 147/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0103 - mae: 0.0752 - val_loss: 0.0722 - val_mae: 0.1958
# Epoch 148/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0108 - mae: 0.0771 - val_loss: 0.0741 - val_mae: 0.1981
# Epoch 149/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0101 - mae: 0.0746 - val_loss: 0.0727 - val_mae: 0.1971
# Epoch 150/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0099 - mae: 0.0734 - val_loss: 0.0724 - val_mae: 0.1963
# Epoch 151/300
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0103 - mae: 0.0749 - val_loss: 0.0763 - val_mae: 0.2022
# Epoch 152/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0104 - mae: 0.0754 - val_loss: 0.0759 - val_mae: 0.1998
# Epoch 153/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0103 - mae: 0.0751 - val_loss: 0.0725 - val_mae: 0.1957
# Epoch 154/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0101 - mae: 0.0745 - val_loss: 0.0729 - val_mae: 0.1962
# Epoch 155/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0103 - mae: 0.0752 - val_loss: 0.0737 - val_mae: 0.2019
# Epoch 156/300
# 28/28 [==============================] - 4s 130ms/step - loss: 0.0104 - mae: 0.0759 - val_loss: 0.0725 - val_mae: 0.1984
# Epoch 157/300
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0109 - mae: 0.0777 - val_loss: 0.0734 - val_mae: 0.1979
# Epoch 158/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0109 - mae: 0.0781 - val_loss: 0.0744 - val_mae: 0.1967
# Epoch 159/300
# 28/28 [==============================] - 3s 119ms/step - loss: 0.0104 - mae: 0.0758 - val_loss: 0.0739 - val_mae: 0.1986
# Epoch 160/300
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0099 - mae: 0.0736 - val_loss: 0.0718 - val_mae: 0.1936
# Epoch 161/300
# 28/28 [==============================] - 4s 130ms/step - loss: 0.0097 - mae: 0.0727 - val_loss: 0.0732 - val_mae: 0.1969
# Epoch 162/300
# 28/28 [==============================] - 4s 127ms/step - loss: 0.0103 - mae: 0.0757 - val_loss: 0.0742 - val_mae: 0.1967
# Epoch 163/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0119 - mae: 0.0820 - val_loss: 0.0822 - val_mae: 0.2157
# Epoch 164/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0153 - mae: 0.0941 - val_loss: 0.0816 - val_mae: 0.2146
# Epoch 165/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0136 - mae: 0.0877 - val_loss: 0.0754 - val_mae: 0.2004
# Epoch 166/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0107 - mae: 0.0771 - val_loss: 0.0764 - val_mae: 0.2057
# Epoch 167/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0104 - mae: 0.0765 - val_loss: 0.0731 - val_mae: 0.1986
# Epoch 168/300
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0096 - mae: 0.0723 - val_loss: 0.0744 - val_mae: 0.1987
# Epoch 169/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0092 - mae: 0.0704 - val_loss: 0.0741 - val_mae: 0.2002
# Epoch 170/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0092 - mae: 0.0705 - val_loss: 0.0733 - val_mae: 0.1976
# Epoch 171/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0090 - mae: 0.0696 - val_loss: 0.0754 - val_mae: 0.2006
# Epoch 172/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0089 - mae: 0.0691 - val_loss: 0.0742 - val_mae: 0.1983
# Epoch 173/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0090 - mae: 0.0698 - val_loss: 0.0748 - val_mae: 0.2016
# Epoch 174/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0090 - mae: 0.0696 - val_loss: 0.0745 - val_mae: 0.1996
# Epoch 175/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0089 - mae: 0.0692 - val_loss: 0.0745 - val_mae: 0.1996
# Epoch 176/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0089 - mae: 0.0688 - val_loss: 0.0740 - val_mae: 0.1984
# Epoch 177/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.
300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0081 - mae: 0.0655 - val_loss: 0.0757 - val_mae: 0.2012
# Epoch 210/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0080 - mae: 0.0651 - val_loss: 0.0759 - val_mae: 0.2018
# Epoch 211/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0080 - mae: 0.0652 - val_loss: 0.0767 - val_mae: 0.2034
# Epoch 212/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0079 - mae: 0.0649 - val_loss: 0.0764 - val_mae: 0.2009
# Epoch 213/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0080 - mae: 0.0651 - val_loss: 0.0764 - val_mae: 0.2009
# Epoch 214/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0079 - mae: 0.0651 - val_loss: 0.0749 - val_mae: 0.2006
# Epoch 215/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0079 - mae: 0.0649 - val_loss: 0.0764 - val_mae: 0.2022
# Epoch 216/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0080 - mae: 0.0653 - val_loss: 0.0764 - val_mae: 0.2011
# Epoch 217/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0081 - mae: 0.0662 - val_loss: 0.0755 - val_mae: 0.2020
# Epoch 218/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0081 - mae: 0.0663 - val_loss: 0.0758 - val_mae: 0.1994
# Epoch 219/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0087 - mae: 0.0690 - val_loss: 0.0783 - val_mae: 0.2042
# Epoch 220/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0086 - mae: 0.0686 - val_loss: 0.0774 - val_mae: 0.2055
# Epoch 221/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0091 - mae: 0.0708 - val_loss: 0.0744 - val_mae: 0.2004
# Epoch 222/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0089 - mae: 0.0702 - val_loss: 0.0779 - val_mae: 0.2031
# Epoch 223/300
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0088 - mae: 0.0696 - val_loss: 0.0775 - val_mae: 0.2047
# Epoch 224/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0087 - mae: 0.0690 - val_loss: 0.0754 - val_mae: 0.1988
# Epoch 225/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0084 - mae: 0.0675 - val_loss: 0.0753 - val_mae: 0.2005
# Epoch 226/300
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0081 - mae: 0.0659 - val_loss: 0.0752 - val_mae: 0.2006
# Epoch 227/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0080 - mae: 0.0656 - val_loss: 0.0761 - val_mae: 0.2002
# Epoch 228/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0079 - mae: 0.0651 - val_loss: 0.0767 - val_mae: 0.2014
# Epoch 229/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0085 - mae: 0.0686 - val_loss: 0.0759 - val_mae: 0.1995
# Epoch 230/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0095 - mae: 0.0729 - val_loss: 0.0789 - val_mae: 0.2047
# Epoch 231/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0089 - mae: 0.0697 - val_loss: 0.0796 - val_mae: 0.2103
# Epoch 232/300
# 28/28 [==============================] - 4s 128ms/step - loss: 0.0101 - mae: 0.0758 - val_loss: 0.0740 - val_mae: 0.1973
# Epoch 233/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0087 - mae: 0.0691 - val_loss: 0.0740 - val_mae: 0.1994
# Epoch 234/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0084 - mae: 0.0682 - val_loss: 0.0773 - val_mae: 0.2044
# Epoch 235/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0088 - mae: 0.0701 - val_loss: 0.0762 - val_mae: 0.2040
# Epoch 236/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0086 - mae: 0.0685 - val_loss: 0.0714 - val_mae: 0.1943
# Epoch 237/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0080 - mae: 0.0659 - val_loss: 0.0777 - val_mae: 0.2043
# Epoch 238/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0082 - mae: 0.0670 - val_loss: 0.0776 - val_mae: 0.2027
# Epoch 239/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0080 - mae: 0.0657 - val_loss: 0.0748 - val_mae: 0.1993
# Epoch 240/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0076 - mae: 0.0638 - val_loss: 0.0748 - val_mae: 0.1988
# Epoch 241/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0075 - mae: 0.0631 - val_loss: 0.0758 - val_mae: 0.2003
# Epoch 242/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0073 - mae: 0.0624 - val_loss: 0.0755 - val_mae: 0.2004
# Epoch 243/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0073 - mae: 0.0623 - val_loss: 0.0771 - val_mae: 0.2027
# Epoch 244/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0072 - mae: 0.0619 - val_loss: 0.0758 - val_mae: 0.2004
# Epoch 245/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0072 - mae: 0.0617 - val_loss: 0.0761 - val_mae: 0.2011
# Epoch 246/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0072 - mae: 0.0617 - val_loss: 0.0764 - val_mae: 0.2017
# Epoch 247/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0072 - mae: 0.0615 - val_loss: 0.0766 - val_mae: 0.2019
# Epoch 248/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0072 - mae: 0.0616 - val_loss: 0.0766 - val_mae: 0.2023
# Epoch 249/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0072 - mae: 0.0620 - val_loss: 0.0787 - val_mae: 0.2053
# Epoch 250/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0073 - mae: 0.0622 - val_loss: 0.0753 - val_mae: 0.2005
# Epoch 251/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0074 - mae: 0.0628 - val_loss: 0.0771 - val_mae: 0.2025
# Epoch 252/300
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0073 - mae: 0.0620 - val_loss: 0.0772 - val_mae: 0.2034
# Epoch 253/300
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0074 - mae: 0.0628 - val_loss: 0.0762 - val_mae: 0.2011
# Epoch 254/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0074 - mae: 0.0629 - val_loss: 0.0761 - val_mae: 0.2010
# Epoch 255/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0074 - mae: 0.0628 - val_loss: 0.0762 - val_mae: 0.2013
# Epoch 256/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0074 - mae: 0.0627 - val_loss: 0.0767 - val_mae: 0.2026
# Epoch 257/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0076 - mae: 0.0642 - val_loss: 0.0754 - val_mae: 0.1998
# Epoch 258/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0075 - mae: 0.0637 - val_loss: 0.0762 - val_mae: 0.2018
# Epoch 259/300
# 28/28 [==============================] - 4s 127ms/step - loss: 0.0077 - mae: 0.0643 - val_loss: 0.0761 - val_mae: 0.2017
# Epoch 260/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0079 - mae: 0.0660 - val_loss: 0.0760 - val_mae: 0.2002
# Epoch 261/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0082 - mae: 0.0667 - val_loss: 0.0779 - val_mae: 0.2035
# Epoch 262/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0078 - mae: 0.0648 - val_loss: 0.0766 - val_mae: 0.2018
# Epoch 263/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0075 - mae: 0.0635 - val_loss: 0.0777 - val_mae: 0.2034
# Epoch 264/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0076 - mae: 0.0645 - val_loss: 0.0754 - val_mae: 0.1992
# Epoch 265/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0075 - mae: 0.0639 - val_loss: 0.0753 - val_mae: 0.1991
# Epoch 266/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0074 - mae: 0.0632 - val_loss: 0.0756 - val_mae: 0.2012
# Epoch 267/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0077 - mae: 0.0648 - val_loss: 0.0784 - val_mae: 0.2060
# Epoch 268/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0077 - mae: 0.0649 - val_loss: 0.0772 - val_mae: 0.2022
# Epoch 269/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0078 - mae: 0.0652 - val_loss: 0.0758 - val_mae: 0.1999
# Epoch 270/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0084 - mae: 0.0680 - val_loss: 0.0775 - val_mae: 0.2053
# Epoch 271/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0089 - mae: 0.0706 - val_loss: 0.0768 - val_mae: 0.2034
# Epoch 272/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0084 - mae: 0.0678 - val_loss: 0.0762 - val_mae: 0.2025
# Epoch 273/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0084 - mae: 0.0688 - val_loss: 0.0775 - val_mae: 0.2035
# Epoch 274/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0077 - mae: 0.0647 - val_loss: 0.0762 - val_mae: 0.2013
# Epoch 275/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0077 - mae: 0.0648 - val_loss: 0.0751 - val_mae: 0.1996
# Epoch 276/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0076 - mae: 0.0642 - val_loss: 0.0780 - val_mae: 0.2060
# Epoch 277/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0075 - mae: 0.0636 - val_loss: 0.0763 - val_mae: 0.2018
# Epoch 278/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0074 - mae: 0.0632 - val_loss: 0.0792 - val_mae: 0.2075
# Epoch 279/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0076 - mae: 0.0641 - val_loss: 0.0783 - val_mae: 0.2049
# Epoch 280/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0079 - mae: 0.0658 - val_loss: 0.0777 - val_mae: 0.2018
# Epoch 281/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0084 - mae: 0.0689 - val_loss: 0.0755 - val_mae: 0.1986
# Epoch 282/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0080 - mae: 0.0661 - val_loss: 0.0788 - val_mae: 0.2065
# Epoch 283/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0075 - mae: 0.0638 - val_loss: 0.0755 - val_mae: 0.1999
# Epoch 284/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0071 - mae: 0.0621 - val_loss: 0.0763 - val_mae: 0.2014
# Epoch 285/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0069 - mae: 0.0605 - val_loss: 0.0765 - val_mae: 0.2016
# Epoch 286/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0071 - mae: 0.0618 - val_loss: 0.0779 - val_mae: 0.2044
# Epoch 287/300
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0073 - mae: 0.0630 - val_loss: 0.0760 - val_mae: 0.2005
# Epoch 288/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0076 - mae: 0.0638 - val_loss: 0.0776 - val_mae: 0.2043
# Epoch 289/300
# 28/28 [==============================] - 3s 125ms/step - loss: 0.0073 - mae: 0.0627 - val_loss: 0.0765 - val_mae: 0.2030
# Epoch 290/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0074 - mae: 0.0629 - val_loss: 0.0752 - val_mae: 0.1998
# Epoch 291/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0070 - mae: 0.0613 - val_loss: 0.0774 - val_mae: 0.2028
# Epoch 292/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0069 - mae: 0.0606 - val_loss: 0.0762 - val_mae: 0.2015
# Epoch 293/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0070 - mae: 0.0608 - val_loss: 0.0770 - val_mae: 0.2020
# Epoch 294/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0069 - mae: 0.0602 - val_loss: 0.0754 - val_mae: 0.1997
# Epoch 295/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0067 - mae: 0.0595 - val_loss: 0.0791 - val_mae: 0.2055
# Epoch 296/300
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0067 - mae: 0.0593 - val_loss: 0.0770 - val_mae: 0.2026
# Epoch 297/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0065 - mae: 0.0585 - val_loss: 0.0759 - val_mae: 0.2006
# Epoch 298/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0065 - mae: 0.0584 - val_loss: 0.0771 - val_mae: 0.2027
# Epoch 299/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0065 - mae: 0.0583 - val_loss: 0.0776 - val_mae: 0.2031
# Epoch 300/300
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0066 - mae: 0.0588 - val_loss: 0.0770 - val_mae: 0.2022

# %%
# Afficher les courbes d'entraînement
plt.figure(figsize=(12, 5))

# Affichage de la perte
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Perte d\'entraînement')
plt.plot(history.history['val_loss'], label='Perte de validation')
plt.title('Perte pendant l\'entraînement')
plt.xlabel('Epoch')
plt.ylabel('Perte')
plt.legend()

# Affichage de la précision
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Précision d\'entraînement')
plt.plot(history.history['val_mae'], label='Précision de validation')
plt.title('mae pendant l\'entraînement')
plt.xlabel('Epoch')
plt.ylabel('mae')
plt.legend()

plt.tight_layout()
plt.show()

# %%
prediction = model.predict(np.expand_dims(X_scaled[1], axis=0))

# %%
# Supposons que X_scaled est votre dataset d'images et Y_scaled sont vos masques/labels
# Nous afficherons l'image originale, la prédiction et le vrai masque côte à côte

num_images =61  # Nombre d'images à afficher
fig, axes = plt.subplots(num_images, 3, figsize=(15, num_images * 3))  # 3 colonnes pour image, prédiction, masque

for i in range(num_images):
    prediction = model.predict(np.expand_dims(X_scaled[i], axis=0))[0]  # Prédire pour une image
    prediction = prediction.reshape(256, 256)  # Ajuster la forme si nécessaire

    # Afficher l'image originale
    axes[i, 0].imshow(X_scaled[i])
    axes[i, 0].set_title(f'Image Originale {i}')
    axes[i, 0].axis('off')

    # Afficher la prédiction
    axes[i, 1].imshow(prediction, cmap='gray')
    axes[i, 1].set_title(f'Prédiction {i}')
    axes[i, 1].axis('off')

    # Afficher le masque vrai
    axes[i, 2].imshow(Y_scaled[i].reshape(256, 256), cmap='gray')  # Ajuster la forme si nécessaire
    axes[i, 2].set_title(f'Masque Réel {i}')
    axes[i, 2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# model.save('seg_dataset2.h5')

# %% [markdown]
# TEST DU MODEL

# %%
from tensorflow.keras.models import load_model
model = load_model('/home/riccardo/Visual_Studio_Code/Grain-segmentation_prjt/Models/seg_dataset2.h5')

# %%
target_size = (256, 256) 

image_path1 = '/home/riccardo/Visual_Studio_Code/Grain-segmentation_prjt/Pct_training/test1.png'
image_path2 = '/home/riccardo/Visual_Studio_Code/Grain-segmentation_prjt/Pct_training/test2.png'
image_path3 = '/home/riccardo/Visual_Studio_Code/Grain-segmentation_prjt/Pct_training/test3.png'
image_path4 = '/home/riccardo/Visual_Studio_Code/Grain-segmentation_prjt/Pct_training/test4.png'
image_path5 = '/home/riccardo/Visual_Studio_Code/Grain-segmentation_prjt/Pct_training/test5.png'


image1 = cv2.imread(image_path1, cv2.IMREAD_COLOR)
image2 = cv2.imread(image_path2, cv2.IMREAD_COLOR)
image3 = cv2.imread(image_path3, cv2.IMREAD_COLOR)
image4 = cv2.imread(image_path4, cv2.IMREAD_COLOR)
image5 = cv2.imread(image_path5, cv2.IMREAD_COLOR)


image1 = np.array(cv2.resize(image1, target_size))/255
image2 = np.array(cv2.resize(image2, target_size))/255
image3 = np.array(cv2.resize(image3, target_size))/255
image4 = np.array(cv2.resize(image4, target_size))/255
image5 = np.array(cv2.resize(image5, target_size))/255

# %%
prediction = model.predict(np.expand_dims(image3, axis=0))

# %%
image = image5
plt.imshow(image)

# %%
prediction = model.predict(np.expand_dims(image, axis=0))
plt.imshow(prediction.reshape(256, 256,1),cmap='gray')

# %%
# Supprimer la dimension de lot et la dimension de canal pour obtenir une image 2D
prediction_2d = prediction.squeeze()

# Appliquer le filtre médian
prediction_denoised = cv2.medianBlur(prediction_2d, 5)

# Afficher l'image débruitée
plt.imshow(prediction_denoised, cmap='gray')
plt.title('Image Débruitée')
plt.axis('off')
plt.show()
